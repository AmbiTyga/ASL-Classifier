# %% [markdown]
# <a href="https://colab.research.google.com/github/AmbiTyga/ASL-Classifier/blob/master/Tweet-collections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ||consumer-key|consumer-secret|access-token|access-token-secret|
# |-|------------|---------------|------------|-------------------|
# |1.|'7yyyT8SL3ZhbZnO2SDAbc95mY'|'2VL25ca3ckKZzv89Efe57qJC67rzFsyovV9V4JELqWAA5H3O9f'|'983655149049528321-RrTBmkk67qpAgOeiBPNjrSIvgi77Vtm'|'0zeSsJmvuPIGQz60PH8fyxw6StMswhmJvqMBJHyC4RGa8'|
# |2.|'afSquKSqkrs8eqrNr8aJ2gZTo'|'0JEyc80fzjo9BT6K99wfaJGZQJWabWgIVyo1vnNNju8Cmlz8R8'|'983655149049528321-gaHXrE4TYGjRNGFbuuhBWT6uoeDqP85'|'tupkn43qGuGoVbIr4SkxLbOitClYJpHRB7guUGkWKeFHV'|
# |3.|'U5B8didckAvhEYbglEGjQZFKy'|'kKYy8kk5Uz6L7Sf81F3Yl2WLCOcVUmfLpoVHaE2nZ9oMFd9Geg'|'983655149049528321-Qfg97mu8ayy4vnPdTbhZ9G5iNEz1QOx'|'lkBYzpG2xJtqoBGBbAhVkfNwHSv4Uws582FfPY0AFMHdr'|
# |4.|'HWXlr3Kvay09d0U2IqBsWM8ml'|'r0418axVb8pTt0NTHq3SX2g5S00aSlSAILstPEMJyXg0P1ZYNS'|'983655149049528321-JhgRvArPCnUEp7aHiDG1mQic2bTRjf5'|'ZfEzo8G70IpgcvcpaQfbMXYgwmCI3tiwKzsCPmAfqWjo2'|
# |5.|'NxxrPJ8RIE6TA7sNw0Gj5p98D'|'cOieHviP3bzkQ9SjVKII5jWR7RWVDQYGRdtXDY9OwYWSjclEBq'|'3178807178-1VS1Mdi7qYoQbuPPRRG5Fa75WmPn2q9hoyxrQBc'|'c0bonCEZUBauXLYqI1I2nouAX250NBjRLn5CYDHkrYTkb'|
# |6.|'UJQWbFqI7cl4Q01SzeGUbKUp5'|'BPpQikbmAsrWmeVRNYbprWe84cYVpFXnMWJyFOh1dxkoo7dHoG'|'983655149049528321-UC9KApH4Fhph2rWLZDJqlsxsHDcb1wx'|'ADfG5LGfqu0jG6Yqn0kqrr1FmUuQlkrfVJ3F4N2Mg5mSS'|

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#@title Download Dataset
# !wget https://botometer.osome.iu.edu/bot-repository/datasets/verified-2019/verified-2019.tar.gz -q
# !mkdir verified
# !tar xzf verified-2019.tar.gz -C verified
# !rm verified-2019.tar.gz
print("Verified-2019 downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/midterm-2018/midterm-2018.tar.gz -q
# !mkdir midterm
# !tar xzf midterm-2018.tar.gz -C midterm
# !rm midterm-2018.tar.gz
print("Midterm-2018 downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/astroturf/astroturf.tar.gz -q
# !mkdir astro
# !tar xzf astroturf.tar.gz -C astro
# !rm astroturf.tar.gz
print("AstroTurf downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/botwiki-2019/botwiki-2019.tar.gz -q
# !mkdir botwiki
# !tar xzf botwiki-2019.tar.gz -C botwiki
# !rm botwiki-2019.tar.gz
print("Botwiki-2019 downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/cresci-stock-2018/cresci-stock-2018.tar.gz -q
# !mkdir stock
# !tar xzf cresci-stock-2018.tar.gz -C stock
# !rm cresci-stock-2018.tar.gz
print("Cresci Stock downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/cresci-rtbust-2019/cresci-rtbust-2019.tar.gz -q
# !mkdir cresci-rtbust
# !tar xzf cresci-rtbust-2019.tar.gz -C cresci-rtbust
# !rm cresci-rtbust-2019.tar.gz
print("Cresci Rtbust downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/gilani-2017/gilani-2017.tar.gz -q
# !mkdir gilani
# !tar xzf gilani-2017.tar.gz -C gilani
# !rm gilani-2017.tar.gz
print("Gilani-17 downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/political-bots-2019/political-bots-2019.tar.gz -q
# !mkdir political
# !tar xzf political-bots-2019.tar.gz -C political
# !rm political-bots-2019.tar.gz
print("Political-bots downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/botometer-feedback-2019/botometer-feedback-2019.tar.gz -q
# !mkdir botometer
# !tar xzf botometer-feedback-2019.tar.gz -C botometer
# !rm botometer-feedback-2019.tar.gz
print("Botometer Feedback downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/vendor-purchased-2019/vendor-purchased-2019.tar.gz -q
# !mkdir vendor
# !tar xzf vendor-purchased-2019.tar.gz -C vendor
# !rm vendor-purchased-2019.tar.gz
print("Vendor Purchased 2019 downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/celebrity-2019/celebrity-2019.tar.gz -q
# !mkdir celebrity
# !tar xzf celebrity-2019.tar.gz -C celebrity
# !rm celebrity-2019.tar.gz
print("Celebrity-2019 downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/pronbots-2019/pronbots-2019.tar.gz -q
# !mkdir pronbots
# !tar xvzf pronbots-2019.tar.gz -C pronbots
# !rm pronbots-2019.tar.gz
print("Pronbots-2019 downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/caverlee-2011/caverlee-2011.zip -q
# !mkdir caverlee
# !unzip -q /content/caverlee-2011.zip -d caverlee 
# !rm caverlee-2011.zip
print("Caverlee-11 downloaded and extracted")

# !wget https://botometer.osome.iu.edu/bot-repository/datasets/varol-2017/varol-2017.dat.gz -q
# !mkdir varol
# !gunzip -dc < varol-2017.dat.gz > varol/varol-2017.dat
# !rm varol-2017.dat.gz
print("Varol-17 downloaded and extracted")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import pickle as pkl
from tqdm import tqdm
import tweepy, time

# %%
# assign the values accordingly 
consumer_key = 'afSquKSqkrs8eqrNr8aJ2gZTo'
consumer_secret = '0JEyc80fzjo9BT6K99wfaJGZQJWabWgIVyo1vnNNju8Cmlz8R8'
access_token= '983655149049528321-gaHXrE4TYGjRNGFbuuhBWT6uoeDqP85'
access_token_secret = 'tupkn43qGuGoVbIr4SkxLbOitClYJpHRB7guUGkWKeFHV'
  
# authorization of consumer key and consumer secret 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
  
# set access to user's access key and access secret  
auth.set_access_token(access_token, access_token_secret) 
  
# calling the api  
api = tweepy.API(auth)

# %% [markdown]
# # Pronbot

# %%
# !wget https://botometer.osome.iu.edu/bot-repository/datasets/pronbots-2019/pronbots-2019.tar.gz -q
# !mkdir pronbots
# !tar xvzf pronbots-2019.tar.gz -C pronbots
# !rm pronbots-2019.tar.gz
print("Pronbots-2019 downloaded and extracted")
# Out:
# pronbots-2019.tsv
# pronbots-2019_tweets.json
# Pronbots-2019 downloaded and extracted

# %%
data = pd.read_csv("/content/pronbots/pronbots-2019.tsv",sep = '\t',header = None)

# %%
data.head()
# Out:
#             0    1
# 0  1111770704  bot
# 1   422386111  bot
# 2    94059036  bot
# 3   419403479  bot
# 4  3141909615  bot

# %%
data[1].value_counts()
# Out:
# bot    21964
# Name: 1, dtype: int64

# %%
bot_ids = data[0].values

# %%
failed = []
done = []
for x in tqdm(bot_ids):
  try:
    done.append(api.user_timeline(x,count = 500))
  except tweepy.RateLimitError:
    print('\nRate Exceeded')
    time.sleep(15*60)
    print("\nStarted")
  except Exception as e:
    failed.append(x)
  time.sleep(1)
# Out:
# 100%|██████████| 2000/2000 [38:35<00:00,  1.16s/it]

# %%
len(done), len(failed)
# Out:
# (137, 1863)

# %%
with open("bot-2000#7.pkl", 'wb') as f:
  pkl.dump(done,f)

# %%
# !mv "/content/bot-2000#7.pkl" "/content/drive/MyDrive/Pronbots"

# %% [markdown]
# # Varol
# 0 = Human
# 1 = Bot

# %%
# !wget https://botometer.osome.iu.edu/bot-repository/datasets/varol-2017/varol-2017.dat.gz -q
# !mkdir varol
# !gunzip -dc < varol-2017.dat.gz > varol/varol-2017.dat
# !rm varol-2017.dat.gz
print("Varol-17 downloaded and extracted")

# %%
data = pd.read_csv("/content/varol/varol-2017.dat",sep = '\t',header=None)

# %%
data
# Out:
#                   0    1
# 0        3098421349  1.0
# 1         554067867  1.0
# 2         256597786  1.0
# 3         103351486  1.0
# 4         199973582  1.0
# ...             ...  ...
# 2568  160302029   0  NaN
# 2569  382361714   0  NaN
# 2570  3528645202  0  NaN
# 2571  3394060059  0  NaN
# 2572  1686033637  0  NaN
#
# [2573 rows x 2 columns]

# %%
ids0 = data[data[1].isna()][0].copy()

# %%
data.loc[ids0.index,0] = ids0.apply(lambda x: x.split()[0])
data.loc[ids0.index,1] = ids0.apply(lambda x: x.split()[1])

# %%
data
# Out:
#                0  1
# 0     3098421349  1
# 1      554067867  1
# 2      256597786  1
# 3      103351486  1
# 4      199973582  1
# ...          ... ..
# 2568   160302029  0
# 2569   382361714  0
# 2570  3528645202  0
# 2571  3394060059  0
# 2572  1686033637  0
#
# [2573 rows x 2 columns]

# %%
bot_ids = data[0][data[1]==1].values

# %%
failed = []
done = []
for x in tqdm(bot_ids):
  try:
    done.append(api.user_timeline(x,count = 500))
  except tweepy.RateLimitError:
    print('\nRate Exceeded')
    time.sleep(15*60)
    print("\nStarted")
  except Exception as e:
    failed.append(x)
  time.sleep(1)
# Out:
# 100%|██████████| 826/826 [19:19<00:00,  1.40s/it]

# %%
with open("bot-826.pkl", 'wb') as f:
  pkl.dump(done,f)

# %%
# !mv "/content/bot-826.pkl" "/content/drive/MyDrive/Varol"

# %%
len(done),len(failed)
# Out:
# (652, 174)

# %% [markdown]
# # Cresci 17

# %%
#@title Download
# !wget https://botometer.osome.iu.edu/bot-repository/datasets/cresci-2017/cresci-2017.csv.zip -q
# !unzip -q cresci-2017.csv.zip
# !mkdir cresci-17
# !unzip -q /content/datasets_full.csv/crowdflower_results.csv.zip -d cresci-17 
# !unzip -q /content/datasets_full.csv/fake_followers.csv.zip -d cresci-17
# !unzip -q /content/datasets_full.csv/genuine_accounts.csv.zip -d cresci-17
# !unzip -q /content/datasets_full.csv/social_spambots_1.csv.zip -d cresci-17
# !unzip -q /content/datasets_full.csv/social_spambots_2.csv.zip -d cresci-17
# !unzip -q /content/datasets_full.csv/social_spambots_3.csv.zip -d cresci-17
# !unzip -q /content/datasets_full.csv/traditional_spambots_1.csv.zip -d cresci-17
# !unzip -q /content/datasets_full.csv/traditional_spambots_2.csv.zip -d cresci-17
# !unzip -q /content/datasets_full.csv/traditional_spambots_3.csv.zip -d cresci-17
# !unzip -q /content/datasets_full.csv/traditional_spambots_4.csv.zip -d cresci-17
# !rm cresci-2017.csv.zip
# !rm datasets_full.csv -r
# !rm /content/cresci-17/__MACOSX -r
print("Cresci-17 downloaded and extracted")
# Out:
# Cresci-17 downloaded and extracted

# %% [markdown]
# ## crowdflower

# %%
crowdflower = pd.read_csv('/content/cresci-17/crowdflower_results.csv/crowdflower_results_detailed.csv')

# %%
crowdflower
# Out:
#        crowdflower_id    channel  ...  twitter_user_id  twitter_screen_name
# 0           911068393     neodev  ...           678033               heathr
# 1           911068393     neodev  ...           678033               heathr
# 2           911068393     neodev  ...           678033               heathr
# 3           911068394  clixsense  ...           806975          mrinaldesai
# 4           911068394      elite  ...           806975          mrinaldesai
# ...               ...        ...  ...              ...                  ...
# 13279       911072847      elite  ...       3308945967      PrizeLotto52491
# 13280       911072847  clixsense  ...       3308945967      PrizeLotto52491
# 13281       911072848    instagc  ...       4331279781       MillionRentals
# 13282       911072848      elite  ...       4331279781       MillionRentals
# 13283       911072848  clixsense  ...       4331279781       MillionRentals
#
# [13284 rows x 11 columns]

# %%
data = crowdflower.drop_duplicates(['twitter_user_id'],ignore_index=True).copy()

# %%
data
# Out:
#       crowdflower_id      channel  ...  twitter_user_id  twitter_screen_name
# 0          911068393       neodev  ...           678033               heathr
# 1          911068394    clixsense  ...           806975          mrinaldesai
# 2          911068395    clixsense  ...           887281                 Payo
# 3          911068396       neodev  ...          1382561               jojoko
# 4          911068397       neodev  ...          1813221             Poormojo
# ...              ...          ...  ...              ...                  ...
# 4423       911072844       neodev  ...       3305460917      CrazyPrize75229
# 4424       911072845    clixsense  ...       3305488912      PrizeTrain55275
# 4425       911072846    clixsense  ...       3307816547       LuckyPick38538
# 4426       911072847  tremorgames  ...       3308945967      PrizeLotto52491
# 4427       911072848      instagc  ...       4331279781       MillionRentals
#
# [4428 rows x 11 columns]

# %%
data = data.loc[:,['twitter_user_id','ground_truth_class']].copy()

# %%
data['ground_truth_class'].value_counts()
# Out:
# spambot    2928
# genuine    1500
# Name: ground_truth_class, dtype: int64

# %%
bot_ids = data['twitter_user_id'][data['ground_truth_class']=='spambot'].values

# %%
failed = []
done = []
for x in tqdm(bot_ids[:1464]):
  try:
    done.append(api.user_timeline(x,count = 500))
  except tweepy.RateLimitError:
    print('\nRate Exceeded')
    time.sleep(15*60)
    print("\nStarted")
  except Exception as e:
    failed.append(x)

with open("/content/drive/MyDrive/Cresci17/Crowdflower/bot-1464#1.pkl", 'wb') as f:
  pkl.dump(done,f)
# Out:
#  61%|██████▏   | 900/1464 [04:10<01:49,  5.13it/s]
# Rate Exceeded
#  62%|██████▏   | 902/1464 [19:10<29:32:03, 189.19s/it]
# Started
# 100%|██████████| 1464/1464 [22:43<00:00,  1.07it/s]

# %%
failed = []
done = []
for x in tqdm(bot_ids[1464:]):
  try:
    done.append(api.user_timeline(x,count = 500))
  except tweepy.RateLimitError:
    print('\nRate Exceeded')
    time.sleep(15*60)
    print("\nStarted")
  except Exception as e:
    failed.append(x)

with open("/content/drive/MyDrive/Cresci17/Crowdflower/bot-1464#2.pkl", 'wb') as f:
  pkl.dump(done,f)
# Out:
#  61%|██████▏   | 900/1464 [05:00<03:20,  2.81it/s]
# Rate Exceeded
#  62%|██████▏   | 901/1464 [20:00<42:16:26, 270.31s/it]
# Started
# 100%|██████████| 1464/1464 [23:07<00:00,  1.05it/s]

# %%
failed = []
done = []
for x in tqdm(human_ids):
  try:
    done.append(api.user_timeline(x,count = 500))
  except tweepy.RateLimitError:
    print('\nRate Exceeded')
    time.sleep(15*60)
    print("\nStarted")
  except Exception as e:
    failed.append(x)

with open("/content/drive/MyDrive/Cresci17/Crowdflower/human-1500.pkl", 'wb') as f:
  pkl.dump(done,f)
# Out:
#  60%|██████    | 900/1500 [06:09<03:32,  2.82it/s]
# Rate Exceeded
#  60%|██████    | 902/1500 [21:10<31:26:20, 189.27s/it]
# Started
# 100%|██████████| 1500/1500 [24:56<00:00,  1.00it/s]

# %% [markdown]
# ## Fake_followers

# %%
ff_tweets = pd.read_csv('/content/cresci-17/fake_followers.csv/tweets.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ff_tweets['user_mentions'] = ff_tweets.text.str.findall(r'(?<![@\w])@(\w{1,25})')
ff_tweets['hashtags'] = ff_tweets.text.str.findall(r'(?<![#\w])#(\w{1,25})')
ff_tweets['symbols'] = ff_tweets.text.str.findall(r'(?<![$\w])$(\w{1,6})')
ff_tweets['urls'] = ff_tweets.text.str.findall(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')

# %%
ff_tweets.replace([],np.NaN,inplace=True)
ff_tweets = ff_tweets[ff_tweets.text.notna()]

# %%
ff_tweets
# Out:
#                             created_at  ...                        urls
# 0       Sat Apr 20 13:19:19 +0000 2013  ...  [https://t.co/iocNIgHxXH.]
# 1       Tue Apr 16 19:31:39 +0000 2013  ...    [http://t.co/AaeTwLucUG]
# 2       Tue Apr 16 17:38:06 +0000 2013  ...    [http://t.co/R1x2vaWXEv]
# 3       Sun Apr 14 15:33:00 +0000 2013  ...    [http://t.co/9xyGLpgiSB]
# 4       Fri Apr 12 15:37:59 +0000 2013  ...    [http://t.co/4NUl8UD9IU]
# ...                                ...  ...                         ...
# 196022  Mon May 06 04:33:01 +0000 2013  ...                          []
# 196023  Fri May 17 00:48:14 +0000 2013  ...                          []
# 196024  Fri May 03 13:38:10 +0000 2013  ...                          []
# 196025  Fri May 17 01:08:54 +0000 2013  ...                          []
# 196026  Fri May 03 13:45:09 +0000 2013  ...                          []
#
# [196007 rows x 27 columns]

# %% [markdown]
# ```
# Note:
# extract entities,
# Do further Analysis
# ```

# %%
fake_ff = pd.read_csv('/content/cresci-17/fake_followers.csv/users.csv')

# %%
Z = [[fake_ff[fake_ff['id']==int(u)].to_dict(),t] for u,t in ff_tweets.groupby('user_id')]

# %%
Z[0][0]
# Out:
# {'contributors_enabled': {11: nan},
#  'created_at': {11: 'Fri Dec 07 13:57:04 +0000 2007'},
#  'default_profile': {11: nan},
#  'default_profile_image': {11: nan},
#  'description': {11: nan},
#  'favourites_count': {11: 7},
#  'follow_request_sent': {11: nan},
#  'followers_count': {11: 171},
#  'following': {11: nan},
#  'friends_count': {11: 1398},
#  'geo_enabled': {11: nan},
#  'id': {11: 10935572},
#  'is_translator': {11: nan},
#  'lang': {11: 'en'},
#  'listed_count': {11: 1},
#  'location': {11: nan},
#  'name': {11: 'clareanderson'},
#  'notifications': {11: nan},
#  'profile_background_color': {11: '642D8B'},
#  'profile_background_image_url': {11: 'http://a0.twimg.com/profile_background_images/117515795/x5f056d8ab627448fb4ffacf4cc0d77c.jpg'},
#  'profile_background_image_url_https': {11: 'https://si0.twimg.com/profile_background_images/117515795/x5f056d8ab627448fb4ffacf4cc0d77c.jpg'},
#  'profile_background_tile': {11: nan},
#  'profile_banner_url': {11: 'https://pbs.twimg.com/profile_banners/10935572/1366464154'},
#  'profile_image_url': {11: 'http://a0.twimg.com/profile_images/3392556920/b1e1bfa75ec9da08ea7734166d0acc80_normal.jpeg'},
#  'profile_image_url_https': {11: 'https://si0.twimg.com/profile_images/3392556920/b1e1bfa75ec9da08ea7734166d0acc80_normal.jpeg'},
#  'profile_link_color': {11: 'FF0000'},
#  'profile_sidebar_border_color': {11: '65B0DA'},
#  'profile_sidebar_fill_color': {11: '7AC3EE'},
#  'profile_text_color': {11: '3D1957'},
#  'profile_use_background_image': {11: 1.0},
#  'protected': {11: nan},
#  'screen_name': {11: 'clarebear4'},
#  'statuses_count': {11: 557},
#  'time_zone': {11: 'London'},
#  'updated': {11: '2013-06-12 18:38:35'},
#  'url': {11: nan},
#  'utc_offset': {11: 0.0},
#  'verified': {11: nan}}

# %%
Z[0][1]
# Out:
#                          created_at  ...                        urls
# 0    Sat Apr 20 13:19:19 +0000 2013  ...  [https://t.co/iocNIgHxXH.]
# 1    Tue Apr 16 19:31:39 +0000 2013  ...    [http://t.co/AaeTwLucUG]
# 2    Tue Apr 16 17:38:06 +0000 2013  ...    [http://t.co/R1x2vaWXEv]
# 3    Sun Apr 14 15:33:00 +0000 2013  ...    [http://t.co/9xyGLpgiSB]
# 4    Fri Apr 12 15:37:59 +0000 2013  ...    [http://t.co/4NUl8UD9IU]
# ..                              ...  ...                         ...
# 551  Fri Feb 06 15:45:00 +0000 2009  ...                          []
# 552  Fri Feb 06 14:06:29 +0000 2009  ...                          []
# 553  Fri Dec 07 13:57:21 +0000 2007  ...                          []
# 554  Tue May 07 16:35:04 +0000 2013  ...    [http://t.co/lmbvGNH0un]
# 555  Fri Apr 26 20:03:44 +0000 2013  ...    [http://t.co/qdoXS12Z5Z]
#
# [556 rows x 27 columns]

# %%
fake_ff.shape
# Out:
# (3351, 38)

# %%
with open('/content/drive/MyDrive/Cresci17/Fake_ff/fake_followers-3351.pkl','wb') as f:
  pkl.dump(Z,f)

# %% [markdown]
# ## Genuine Accounts

# %%
genuine_tweets = pd.read_csv('/content/cresci-17/genuine_accounts.csv/tweets.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
genuine_tweets['user_mentions'] = genuine_tweets.text.str.findall(r'(?<![@\w])@(\w{1,25})')
genuine_tweets['hashtags'] = genuine_tweets.text.str.findall(r'(?<![#\w])#(\w{1,25})')
genuine_tweets['symbols'] = genuine_tweets.text.str.findall(r'(?<![$\w])$(\w{1,6})')
genuine_tweets['urls'] = genuine_tweets.text.str.findall(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')

# %%
genuine_tweets.replace([],np.NaN,inplace=True)
genuine_tweets = genuine_tweets[genuine_tweets.text.notna()]

# %%
genuine_tweets
# Out:
#                          id  ...                      urls
# 0        593932392663912449  ...                        []
# 1        593895316719423488  ...                        []
# 2        593880638069018624  ...                        []
# 3        593847955536252928  ...                        []
# 4        593847687847350272  ...                        []
# ...                     ...  ...                       ...
# 2839356  546418822677532673  ...  [http://t.co/YciJW35Hza]
# 2839357  546379158251929600  ...  [http://t.co/jlbwyUEwoy]
# 2839358  578751592213700608  ...              [http://t.c]
# 2839359  546379003465314306  ...  [http://t.co/IOIiKF5qHO]
# 2839360  588093827501527040  ...  [http://t.co/mXB2w5J9bn]
#
# [2826790 rows x 29 columns]

# %% [markdown]
# ```
# Note:
# extract entities,
# Do further Analysis
# ```

# %%
genuine_users = pd.read_csv('/content/cresci-17/genuine_accounts.csv/users.csv')

# %%
G = [[genuine_users[genuine_users['id']==int(u)].to_dict(),t] for u,t in genuine_tweets.groupby('user_id')]

# %%
G[0][0]
# Out:
# {'contributors_enabled': {2274: nan},
#  'crawled_at': {2274: '2015-05-01 12:57:24'},
#  'created_at': {2274: 'Mon Jan 22 01:57:38 +0000 2007'},
#  'default_profile': {2274: nan},
#  'default_profile_image': {2274: nan},
#  'description': {2274: 'Comic. Writer. Speaker. My heart is hardwired to my brain.   Instagram: @heathr   Podcast: http://t.co/l470r0IcVc   Began: #loveislove'},
#  'favourites_count': {2274: 3804},
#  'follow_request_sent': {2274: nan},
#  'followers_count': {2274: 7065},
#  'following': {2274: nan},
#  'friends_count': {2274: 1822},
#  'geo_enabled': {2274: nan},
#  'id': {2274: 678033},
#  'is_translator': {2274: nan},
#  'lang': {2274: 'en'},
#  'listed_count': {2274: 596},
#  'location': {2274: 'OAK '},
#  'name': {2274: 'Heather Gold'},
#  'notifications': {2274: nan},
#  'profile_background_color': {2274: 'FFFFFF'},
#  'profile_background_image_url': {2274: 'http://pbs.twimg.com/profile_background_images/441754008814768128/sS-4Icak.jpeg'},
#  'profile_background_image_url_https': {2274: 'https://pbs.twimg.com/profile_background_images/441754008814768128/sS-4Icak.jpeg'},
#  'profile_background_tile': {2274: 1.0},
#  'profile_banner_url': {2274: 'https://pbs.twimg.com/profile_banners/678033/1399930531'},
#  'profile_image_url': {2274: 'http://pbs.twimg.com/profile_images/554444482507063298/85l1bTdv_normal.jpeg'},
#  'profile_image_url_https': {2274: 'https://pbs.twimg.com/profile_images/554444482507063298/85l1bTdv_normal.jpeg'},
#  'profile_link_color': {2274: 'FF5300'},
#  'profile_sidebar_border_color': {2274: 'FFFFFF'},
#  'profile_sidebar_fill_color': {2274: 'E0FF92'},
#  'profile_text_color': {2274: '000000'},
#  'profile_use_background_image': {2274: nan},
#  'protected': {2274: nan},
#  'screen_name': {2274: 'heathr'},
#  'statuses_count': {2274: 45825},
#  'test_set_1': {2274: 0},
#  'test_set_2': {2274: 0},
#  'time_zone': {2274: 'Eastern Time (US & Canada)'},
#  'timestamp': {2274: '2007-01-22 02:57:38'},
#  'updated': {2274: '2016-03-15 16:05:16'},
#  'url': {2274: 'http://t.co/98fWa0t873'},
#  'utc_offset': {2274: -14400.0},
#  'verified': {2274: nan}}

# %%
G[0][1]
# Out:
#                       id  ... urls
# 0     593932392663912449  ...   []
# 1     593895316719423488  ...   []
# 2     593880638069018624  ...   []
# 3     593847955536252928  ...   []
# 4     593847687847350272  ...   []
# ...                  ...  ...  ...
# 3190  530894171100291072  ...   []
# 3191  530872722083942401  ...   []
# 3192  530854583577227264  ...   []
# 3193  530848406575390720  ...   []
# 3194  530843999313993728  ...   []
#
# [3195 rows x 29 columns]

# %%
genuine_users.shape
# Out:
# (3474, 42)

# %%
with open('/content/drive/MyDrive/Cresci17/Genuine_ACC/genuine_ACC-3474.pkl','wb') as f:
  pkl.dump(G,f)

# %% [markdown]
# ## social_spambots

# %%
ss_tweets = pd.read_csv('/content/cresci-17/genuine_accounts.csv/tweets.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
genuine_tweets['user_mentions'] = genuine_tweets.text.str.findall(r'(?<![@\w])@(\w{1,25})')
genuine_tweets['hashtags'] = genuine_tweets.text.str.findall(r'(?<![#\w])#(\w{1,25})')
genuine_tweets['symbols'] = genuine_tweets.text.str.findall(r'(?<![$\w])$(\w{1,6})')
genuine_tweets['urls'] = genuine_tweets.text.str.findall(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')

# %%
genuine_tweets.replace([],np.NaN,inplace=True)
genuine_tweets = genuine_tweets[genuine_tweets.text.notna()]

# %%
genuine_tweets
# Out:
#                          id  ...                      urls
# 0        593932392663912449  ...                        []
# 1        593895316719423488  ...                        []
# 2        593880638069018624  ...                        []
# 3        593847955536252928  ...                        []
# 4        593847687847350272  ...                        []
# ...                     ...  ...                       ...
# 2839356  546418822677532673  ...  [http://t.co/YciJW35Hza]
# 2839357  546379158251929600  ...  [http://t.co/jlbwyUEwoy]
# 2839358  578751592213700608  ...              [http://t.c]
# 2839359  546379003465314306  ...  [http://t.co/IOIiKF5qHO]
# 2839360  588093827501527040  ...  [http://t.co/mXB2w5J9bn]
#
# [2826790 rows x 29 columns]

# %% [markdown]
# ```
# Note:
# extract entities,
# Do further Analysis
# ```

# %%
genuine_users = pd.read_csv('/content/cresci-17/genuine_accounts.csv/users.csv')

# %%
G = [[genuine_users[genuine_users['id']==int(u)].to_dict(),t] for u,t in genuine_tweets.groupby('user_id')]

# %%
G[0][0]
# Out:
# {'contributors_enabled': {2274: nan},
#  'crawled_at': {2274: '2015-05-01 12:57:24'},
#  'created_at': {2274: 'Mon Jan 22 01:57:38 +0000 2007'},
#  'default_profile': {2274: nan},
#  'default_profile_image': {2274: nan},
#  'description': {2274: 'Comic. Writer. Speaker. My heart is hardwired to my brain.   Instagram: @heathr   Podcast: http://t.co/l470r0IcVc   Began: #loveislove'},
#  'favourites_count': {2274: 3804},
#  'follow_request_sent': {2274: nan},
#  'followers_count': {2274: 7065},
#  'following': {2274: nan},
#  'friends_count': {2274: 1822},
#  'geo_enabled': {2274: nan},
#  'id': {2274: 678033},
#  'is_translator': {2274: nan},
#  'lang': {2274: 'en'},
#  'listed_count': {2274: 596},
#  'location': {2274: 'OAK '},
#  'name': {2274: 'Heather Gold'},
#  'notifications': {2274: nan},
#  'profile_background_color': {2274: 'FFFFFF'},
#  'profile_background_image_url': {2274: 'http://pbs.twimg.com/profile_background_images/441754008814768128/sS-4Icak.jpeg'},
#  'profile_background_image_url_https': {2274: 'https://pbs.twimg.com/profile_background_images/441754008814768128/sS-4Icak.jpeg'},
#  'profile_background_tile': {2274: 1.0},
#  'profile_banner_url': {2274: 'https://pbs.twimg.com/profile_banners/678033/1399930531'},
#  'profile_image_url': {2274: 'http://pbs.twimg.com/profile_images/554444482507063298/85l1bTdv_normal.jpeg'},
#  'profile_image_url_https': {2274: 'https://pbs.twimg.com/profile_images/554444482507063298/85l1bTdv_normal.jpeg'},
#  'profile_link_color': {2274: 'FF5300'},
#  'profile_sidebar_border_color': {2274: 'FFFFFF'},
#  'profile_sidebar_fill_color': {2274: 'E0FF92'},
#  'profile_text_color': {2274: '000000'},
#  'profile_use_background_image': {2274: nan},
#  'protected': {2274: nan},
#  'screen_name': {2274: 'heathr'},
#  'statuses_count': {2274: 45825},
#  'test_set_1': {2274: 0},
#  'test_set_2': {2274: 0},
#  'time_zone': {2274: 'Eastern Time (US & Canada)'},
#  'timestamp': {2274: '2007-01-22 02:57:38'},
#  'updated': {2274: '2016-03-15 16:05:16'},
#  'url': {2274: 'http://t.co/98fWa0t873'},
#  'utc_offset': {2274: -14400.0},
#  'verified': {2274: nan}}

# %%
G[0][1]
# Out:
#                       id  ... urls
# 0     593932392663912449  ...   []
# 1     593895316719423488  ...   []
# 2     593880638069018624  ...   []
# 3     593847955536252928  ...   []
# 4     593847687847350272  ...   []
# ...                  ...  ...  ...
# 3190  530894171100291072  ...   []
# 3191  530872722083942401  ...   []
# 3192  530854583577227264  ...   []
# 3193  530848406575390720  ...   []
# 3194  530843999313993728  ...   []
#
# [3195 rows x 29 columns]

# %%
genuine_users.shape
# Out:
# (3474, 42)

# %%
with open('/content/drive/MyDrive/Cresci17/Genuine_ACC/genuine_ACC-3474.pkl','wb') as f:
  pkl.dump(G,f)

# %% [markdown]
# ## Traditional Spambots

# %%
pd.read_csv("/content/cresci-17/traditional_spambots_2.csv/users.csv")
# Out:
#             id             name  ...           crawled_at              updated
# 0   2355955040  Prize Giveaways  ...  2014-05-05 21:59:19  2016-03-14 15:46:02
# 1   2368624550  Prize Giveaways  ...  2014-05-05 21:59:19  2016-03-14 15:46:02
# 2   2355950858      Prize Crazy  ...  2014-05-05 21:59:19  2016-03-14 15:46:02
# 3   2357744766      Prize World  ...  2014-05-05 21:59:19  2016-03-14 15:46:03
# 4   2362454995     Prize Rocket  ...  2014-05-05 21:59:19  2016-03-14 15:46:03
# ..         ...              ...  ...                  ...                  ...
# 95  2368584738      Prize Lotto  ...  2014-05-05 21:59:19  2016-03-14 15:48:35
# 96  2368468476      Prize Crazy  ...  2014-05-05 21:59:19  2016-03-14 15:48:35
# 97  2330520211       Prize Boat  ...  2014-05-05 21:59:19  2016-03-14 15:48:36
# 98  2341025366      Prize World  ...  2014-05-05 21:59:19  2016-03-14 15:48:36
# 99  2343033816     Prize Tweets  ...  2014-05-05 21:59:19  2016-03-14 15:48:36
#
# [100 rows x 40 columns]

# %% [markdown]
# # Celebrity

# %%
# !wget https://botometer.osome.iu.edu/bot-repository/datasets/celebrity-2019/celebrity-2019.tar.gz -q
# !mkdir celebrity
# !tar xzf celebrity-2019.tar.gz -C celebrity
# !rm celebrity-2019.tar.gz
print("Celebrity-2019 downloaded and extracted")

# %%
human_ids = pd.read_csv("/content/celebrity/celebrity-2019.tsv",sep = '\t',header=None)[0].values

# %%
failedNew = []
done = []
for x in tqdm(failed):
  try:
    done.append(api.user_timeline(x,count = 500))
  except tweepy.RateLimitError:
    print('\nRate Exceeded')
    time.sleep(15*60)
    print("\nStarted")
  except Exception as e:
    failedNew.append(x)
# Out:
#  60%|██████    | 900/1500 [07:48<05:08,  1.94it/s]
# Rate Exceeded
#  60%|██████    | 901/1500 [22:48<44:59:51, 270.44s/it]
# Started
# 100%|██████████| 1500/1500 [27:57<00:00,  1.12s/it]

# %%
with open("human-1500#4.pkl", 'wb') as f:
  pkl.dump(done,f)

# %%
# !mv "/content/human-1500#4.pkl" "/content/drive/MyDrive/Celebrity"

# %%
len(done),len(failedNew)
# Out:
# (1437, 62)

# %%
# !mv  "/content/drive/MyDrive/Celebrity" /content/

# %%
!7z a Celebrity.7z Celebrity
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive:
# 2 folders, 4 files, 4091836867 bytes (3903 MiB)
#
# Creating archive: Celebrity.7z
#
# Items to compress: 6
#
# 100% 4 + Celebrity/human-1500.pkl
# Files read from disk: 4
# Archive size: 562648610 bytes (537 MiB)
# Everything is Ok

# %%
# !mv  /content/Celebrity.7z "/content/drive/MyDrive"
